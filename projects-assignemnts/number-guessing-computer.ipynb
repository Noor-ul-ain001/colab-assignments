# %% [markdown]
# # ***number-guessing-computer***

# %%
import random

def computer_guess():
    print("Think of a number between 1 and 100, and I will try to guess it!")
    low, high = 1, 100
    attempts = 0

    while True:
        guess = random.randint(low, high)
        attempts += 1

        print(f"Is it {guess}? (Enter 'h' if too high, 'l' if too low, 'c' if correct)")
        feedback = input().strip().lower()

        if feedback == 'c':
            print(f"Yay! I guessed your number {guess} in {attempts} attempts!")
            break
        elif feedback == 'h':
            high = guess - 1
        elif feedback == 'l':
            low = guess + 1
        else:
            print("Invalid input. Please enter 'h', 'l', or 'c'.")

computer_guess()
# Out:
# Think of a number between 1 and 100, and I will try to guess it!
# Is it 56? (Enter 'h' if too high, 'l' if too low, 'c' if correct)
# h
# Is it 25? (Enter 'h' if too high, 'l' if too low, 'c' if correct)
# l
# Is it 32? (Enter 'h' if too high, 'l' if too low, 'c' if correct)
# l
# Is it 38? (Enter 'h' if too high, 'l' if too low, 'c' if correct)
# h
# Is it 33? (Enter 'h' if too high, 'l' if too low, 'c' if correct)
# l
# Is it 36? (Enter 'h' if too high, 'l' if too low, 'c' if correct)
# h
# Is it 34? (Enter 'h' if too high, 'l' if too low, 'c' if correct)
# l
# Is it 35? (Enter 'h' if too high, 'l' if too low, 'c' if correct)
# c
# Yay! I guessed your number 35 in 8 attempts!
